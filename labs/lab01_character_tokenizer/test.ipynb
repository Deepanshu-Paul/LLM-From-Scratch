# %%
test = "hello"
ls =[]
for ch in test:
    ls.append(ch)
ls = set(ls)
ls
# Out:
# hello

# %%
unique_chars = set(test)
unique_chars
# Out:
# {'e', 'h', 'l', 'o'}

# %%
dict = {ch: i for i, ch in enumerate(unique_chars)}

# %%
dict
# Out:
# {'o': 0, 'l': 1, 'h': 2, 'e': 3}

# %%
for i, ch in enumerate(unique_chars):
    print(i, ch)
# Out:
# 0 o
# 1 l
# 2 h
# 3 e

# %%
char_to_id = {ch: i for i, ch in enumerate(unique_chars)}

# %%
id_to_char = {i: ch for i, ch in enumerate(unique_chars)}

# %%
id_to_char
# Out:
# {0: 'o', 1: 'l', 2: 'h', 3: 'e'}

# %%
char_to_id
# Out:
# {'o': 0, 'l': 1, 'h': 2, 'e': 3}

# %%
tokenizer = CharacterTokenizer()

tokenizer.fit("hello")

encoded = tokenizer.encode("hello")
print(encoded)

decoded = tokenizer.decode(encoded)
print(decoded)

# %%
text = "hello"
unique_chars = ['<unk>'] + sorted(set(text))
unique_chars
# Out:
# ['<unk>', 'e', 'h', 'l', 'o']
